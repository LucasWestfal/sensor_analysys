# %% [markdown]
# ## Análise exploratória com o intuito de verificar que os dados estão sendo recolhidos de forma correta

# %%
import numpy as np
import pandas as pd

# %%
raw_data = pd.read_csv('data/recording_2/teste_de_consistencia',  sep=", | -> ", names = ["timestamp", "intern_clock", 7, 6, 8, 5, 3, 1, 2, 4], engine = "python")
cols = ["timestamp", "intern_clock", 1, 2, 3, 4, 5, 6, 7, 8]
raw_data = raw_data[cols]
raw_data.drop('timestamp', inplace=True, axis=1)
raw_data = raw_data.astype({1:"int", 2:"int", 3:"int", 4:"int", 5:"int", 6:"int", 7:"int", 8:"int"})
raw_data.drop(1, inplace=True, axis=1)
raw_data.drop(2, inplace=True, axis=1)
raw_data.drop(3, inplace=True, axis=1)
raw_data.drop(4, inplace=True, axis=1)
raw_data
# Out:
#       intern_clock        5        6        7       8
# 0             2503  1266764  2300814 -3575469  285017
# 1             2587  1266701  2300835 -3575533  285044
# 2             2676  1266674  2300821 -3575599  285151
# 3             2764  1266561  2300827 -3575720  285290
# 4             2853  1266370  2300946 -3575860  285334
# ...            ...      ...      ...      ...     ...
# 6706        659892  1178804  2319493 -3409593  320684
# 6707        659990  1178862  2319453 -3409571  320656
# 6708        660087  1178755  2319451 -3409674  320620
# 6709        660186  1178738  2319603 -3409661  320771
# 6710        660284  1178963  2319644 -3409627  320812
#
# [6711 rows x 5 columns]

# %%
from matplotlib import pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(raw_data["intern_clock"]/1000, raw_data[5], s=1, c='b', marker="s", label='5')
ax1.scatter(raw_data["intern_clock"]/1000, raw_data[6], s=1, c='g', marker="s", label='6')
ax1.scatter(raw_data["intern_clock"]/1000, raw_data[7], s=1, c='y', marker="s", label='7')
ax1.scatter(raw_data["intern_clock"]/1000, raw_data[8], s=1, c='r', marker="s", label='8')
plt.legend(loc='upper left')

plt.xlabel("Tempo em segundos")
plt.ylabel("valor do sensor")

plt.savefig("integridade_dados")

plt.show()

# %%
ax1 = raw_data.plot.scatter(x='intern_clock',
                      y=5,
                      c='DarkBlue')

# %%
ax1 = raw_data.plot.scatter(x='intern_clock',
                      y=6,
                      c='DarkBlue')

# %%
ax1 = raw_data.plot.scatter(x='intern_clock',
                      y=7,
                      c='DarkBlue')

# %%
ax1 = raw_data.plot.scatter(x='intern_clock',
                      y=8,
                      c='DarkBlue')
